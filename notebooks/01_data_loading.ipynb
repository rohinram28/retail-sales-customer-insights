# %%
import pandas as pd

# Load Excel file
df = pd.read_excel("../data/retail_sales_dataset.xlsx")

# Preview the data
df.head()
# Out:
#   CustomerID FirstName LastName Gender  BirthDate               City  \
# 0       C001   Michael    Davis      M 1996-09-11        Osborneport
# 1       C002   Michael   Miller      M 1959-08-18  New Gabrielleport
# 2       C003     Carol     Hays      F 2005-04-19         Port Allen
# 3       C004    Joseph     Ward      M 1992-06-16  East Edgarborough
# 4       C005     Jamie  Salinas      M 1992-06-18      Port Kimberly
#
#     JoinDate
# 0 2022-09-25
# 1 2020-11-03
# 2 2024-02-12
# 3 2024-09-09
# 4 2022-02-24

# %%
xls = pd.ExcelFile("../data/retail_sales_dataset.xlsx")
xls.sheet_names
# Out:
# ['Customers', 'Products', 'Stores', 'Transactions']

# %%
customers = pd.read_excel("../data/retail_sales_dataset.xlsx", sheet_name=0)
products  = pd.read_excel("../data/retail_sales_dataset.xlsx", sheet_name=1)
stores     = pd.read_excel("../data/retail_sales_dataset.xlsx", sheet_name=2)
transactions = pd.read_excel("../data/retail_sales_dataset.xlsx", sheet_name=3)
customers.head()
products.head()
stores.head()
transactions.head()

#Inspect column names
customers.columns.tolist()
products.columns.tolist()
stores.columns.tolist()
transactions.columns.tolist()
# Out:
# ['TransactionID',
#  'Date',
#  'CustomerID',
#  'ProductID',
#  'StoreID',
#  'Quantity',
#  'Discount',
#  'PaymentMethod']

# %%
products.columns.tolist()
# Out:
# ['ProductID',
#  'ProductName',
#  'Category',
#  'SubCategory',
#  'UnitPrice',
#  'CostPrice']

# %%
transactions.columns.tolist()
# Out:
# ['TransactionID',
#  'Date',
#  'CustomerID',
#  'ProductID',
#  'StoreID',
#  'Quantity',
#  'Discount',
#  'PaymentMethod']
